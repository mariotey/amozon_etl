# %%
import os
import pandas as pd
from datasets import load_dataset
import ast
from tqdm import tqdm
tqdm.pandas()

# Retrieved from: https://amazon-reviews-2023.github.io/
# NOTE: Use 2023 dataset as it is larger, more descriptive, more granular and cleaner compared to
#       previous datasets.
# NOTE: This dataset (McAuley-Lab/Amazon-Reviews-2023, configuration: raw_review_Software) was
#       extracted using this notebook on 11 Februrary 2026, based on the latest locally cached
#       version available at that time. As the dataset may be updated, restructured, or modified
#       by the authors in the future, results generated from this notebook may differ depending
#       on the dataset version used.

dataset_name = "McAuley-Lab/Amazon-Reviews-2023"

# NOTE: There are 33 categories + Unknown. Software is a subset.
category = "Software"

# %% [markdown]
# ### Load User Reviews

# %%
#######################################################################################################
# Data Fields for User Reviews
#######################################################################################################
#
# - rating (float)             -->   Rating of the product (from 1.0 to 5.0)
# - title (str)                -->   Title of the user review
# - text (str)                 -->   Text body of the user review
# - images (list)              -->   Images that users post after they have received the product
#                                    Each image has different sizes (small, medium, large), represented
#                                    by the small_image_url, medium_image_url, and large_image_url
#                                    respectively
# - asin (str)                 -->   ID of the product
# - parent_asin (str)          -->   Parent ID of the product. Note: Products with different colors,
#                                    styles, sizes usually belong to the same parent ID. The “asin”
#                                    in previous Amazon datasets is actually parent ID. Please use
#                                    parent ID to find product meta
# - user_id (str)              -->   ID of the reviewer
# - timestamp (int)            -->   Time of the review (unix time)
# - verified_purchase (bool)   -->   User purchase verification
# - helpful_vote (int)         -->   Helpful votes of the review
#
#######################################################################################################

review_dataset = load_dataset(dataset_name, f"raw_review_{category}")

all_reviews = [review for review in tqdm(review_dataset["full"])]
review_df = pd.DataFrame(all_reviews)

review_df
# Out:
# Using the latest cached version of the dataset since McAuley-Lab/Amazon-Reviews-2023 couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'raw_review_Software' at C:\Users\user\.cache\huggingface\datasets\McAuley-Lab___amazon-reviews-2023\raw_review_Software\0.0.0\16b76e0823d73bb8cff1e9c5e3e37dbc46ae3daee380417ae141f5e67d3ea8e8 (last modified on Sun Dec 21 21:48:24 2025).
# 100%|██████████| 4880181/4880181 [07:04<00:00, 11501.34it/s]
#          rating                                     title  \
# 0           1.0                                   malware
# 1           5.0                               Lots of Fun
# 2           5.0                         Light Up The Dark
# 3           4.0                                  Fun game
# 4           4.0  I am not that good at it but my kids are
# ...         ...                                       ...
# 4880176     5.0                                       Gog
# 4880177     1.0                           WORST GAME EVER
# 4880178     5.0                                 better!!!
# 4880179     5.0         It Has Everything I Need And More
# 4880180     5.0                                  Huge fan
#
#                                                       text images        asin  \
# 0                                       mcaffee IS malware     []  B07BFS3G7P
# 1        I love playing tapped out because it is fun to...     []  B00CTQ6SIG
# 2        I love this flashlight app!  It really illumin...     []  B0066WJLU6
# 3                                 One of my favorite games     []  B00KCYMAWK
# 4        Cute game. I am not that good at it but my kid...     []  B00P1RK566
# ...                                                    ...    ...         ...
# 4880176                Very fun and addictive and exciting     []  B0763N3MVW
# 4880177  WORST GAME EVER TOXIC PEOPLE AND BAD CONNECTIO...     []  B00ET56Y48
# 4880178  This fabulous game is 10000 times better than ...     []  B009ZKSPDK
# 4880179  Awesome! I upgraded from CorelDraw 8. I was wo...     []  B00M9J3IOA
# 4880180  Omg so fun it keeps me playing btw let's go ga...     []  B01I5OMSKM
#
#         parent_asin                       user_id      timestamp  \
# 0        B0BQSK9QCF  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  1562182632076
# 1        B00CTQ6SIG  AHSPLDNW5OOUK2PLH7GXLACFBZNQ  1424120336000
# 2        B0066WJLU6  AHSPLDNW5OOUK2PLH7GXLACFBZNQ  1362399267000
# 3        B00KCYMAWK  AH6CATODIVPVUOJEWHRSRCSKAOHA  1561061428662
# 4        B00P1RK566  AEINY4XOINMMJCK5GZ3M6MMHBN6A  1418257196000
# ...             ...                           ...            ...
# 4880176  B0763N3MVW  AGOKECUMAI3W6MC7A7KBFBJVPN7Q  1608919468753
# 4880177  B00ET56Y48  AH6AMUNDOSZ2SGDIDMYSRE4RNMDQ  1609973647689
# 4880178  B009ZKSPDK  AH4PJ73QN75AJM5VSCT53AOADCGA  1369722216000
# 4880179  B00M9J3IOA  AHQETDYKHVDNGMGBWVJL6VJXJGFQ  1472923291000
# 4880180  B01I5OMSKM  AH22767FROBCSHB4Y3M4O37QETIQ  1563133201259
#
#          helpful_vote  verified_purchase
# 0                   0              False
# 1                   0               True
# 2                   0               True
# 3                   0               True
# 4                   0               True
# ...               ...                ...
# 4880176             0               True
# 4880177             1               True
# 4880178             2               True
# 4880179             0               True
# 4880180             0               True
#
# [4880181 rows x 10 columns]

# %%
modified_review_df = review_df.copy()

modified_review_df["rating"] = pd.to_numeric(modified_review_df["rating"], errors="coerce")
modified_review_df["title"] = modified_review_df["title"].str.strip().str.lower()
modified_review_df["text"] = modified_review_df["text"].str.strip().str.lower()
modified_review_df["images"] = modified_review_df["images"].astype(str)
modified_review_df["asin"] = modified_review_df["asin"].str.lower()
modified_review_df["parent_asin"] = modified_review_df["parent_asin"].str.lower()
modified_review_df["user_id"] = modified_review_df["user_id"].str.lower()
modified_review_df["date"] = pd.to_datetime(modified_review_df["timestamp"], unit="ms").dt.date

# Reorder columns
modified_review_df = modified_review_df[[
    "asin",
    "parent_asin",
    "user_id",
    # "timestamp",
    "date",
    "title",
    "text",
    "images",
    "verified_purchase",
    "helpful_vote",
    "rating"
]]

# Rename columns
modified_review_df = modified_review_df.rename(columns={
    "date": "review_date",
    "title": "review_title",
    "text": "review_text",
    "images": "review_images",
    "rating": "review_rating"
})

modified_review_df
# Out:
#                asin parent_asin                       user_id review_date  \
# 0        b07bfs3g7p  b0bqsk9qcf  agci7fah4gl5fi65hylkwtmfz2cq  2019-07-03
# 1        b00ctq6sig  b00ctq6sig  ahspldnw5oouk2plh7gxlacfbznq  2015-02-16
# 2        b0066wjlu6  b0066wjlu6  ahspldnw5oouk2plh7gxlacfbznq  2013-03-04
# 3        b00kcymawk  b00kcymawk  ah6catodivpvuojewhrsrcskaoha  2019-06-20
# 4        b00p1rk566  b00p1rk566  aeiny4xoinmmjck5gz3m6mmhbn6a  2014-12-11
# ...             ...         ...                           ...         ...
# 4880176  b0763n3mvw  b0763n3mvw  agokecumai3w6mc7a7kbfbjvpn7q  2020-12-25
# 4880177  b00et56y48  b00et56y48  ah6amundosz2sgdidmysre4rnmdq  2021-01-06
# 4880178  b009zkspdk  b009zkspdk  ah4pj73qn75ajm5vsct53aoadcga  2013-05-28
# 4880179  b00m9j3ioa  b00m9j3ioa  ahqetdykhvdngmgbwvjl6vjxjgfq  2016-09-03
# 4880180  b01i5omskm  b01i5omskm  ah22767frobcshb4y3m4o37qetiq  2019-07-14
#
#                                      review_title  \
# 0                                         malware
# 1                                     lots of fun
# 2                               light up the dark
# 3                                        fun game
# 4        i am not that good at it but my kids are
# ...                                           ...
# 4880176                                       gog
# 4880177                           worst game ever
# 4880178                                 better!!!
# 4880179         it has everything i need and more
# 4880180                                  huge fan
#
#                                                review_text review_images  \
# 0                                       mcaffee is malware            []
# 1        i love playing tapped out because it is fun to...            []
# 2        i love this flashlight app!  it really illumin...            []
# 3                                 one of my favorite games            []
# 4        cute game. i am not that good at it but my kid...            []
# ...                                                    ...           ...
# 4880176                very fun and addictive and exciting            []
# 4880177  worst game ever toxic people and bad connectio...            []
# 4880178  this fabulous game is 10000 times better than ...            []
# 4880179  awesome! i upgraded from coreldraw 8. i was wo...            []
# 4880180  omg so fun it keeps me playing btw let's go ga...            []
#
#          verified_purchase  helpful_vote  review_rating
# 0                    False             0            1.0
# 1                     True             0            5.0
# 2                     True             0            5.0
# 3                     True             0            4.0
# 4                     True             0            4.0
# ...                    ...           ...            ...
# 4880176               True             0            5.0
# 4880177               True             1            1.0
# 4880178               True             2            5.0
# 4880179               True             0            5.0
# 4880180               True             0            5.0
#
# [4880181 rows x 10 columns]

# %% [markdown]
# ### Load Item Metadata

# %%
#######################################################################################################
# Data Fields for Item Metadata
#######################################################################################################
#
# - main_category (str)	       -->   Main category (i.e., domain) of the product
# - title (str)	               -->   Name of the product
# - average_rating (float)     -->   Rating of the product shown on the product page
# - rating_number (int)        -->   Number of ratings in the product
# - features (list)            -->   Bullet-point format features of the product
# - description (list)         -->   Description of the product
# - price (float)              -->   Price in US dollars (at time of crawling)
# - images (list)              -->   Images of the product. Each image has different sizes (thumb, large,
#                                    hi_res). The “variant” field shows the position of image
# - videos (list)              -->   Videos of the product including title and url
# - store (str)	               -->   Store name of the product
# - categories (list)	       -->   Hierarchical categories of the product
# - details (dict)             -->   Product details, including materials, brand, sizes, etc
# - parent_asin (str)	       -->   Parent ID of the product
# - bought_together (list)     -->   Recommended bundles from the websites
#
#######################################################################################################

meta_dataset = load_dataset(dataset_name,f"raw_meta_{category}", split="full")

meta_df = pd.DataFrame(meta_dataset)

meta_df
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Using the latest cached version of the dataset since McAuley-Lab/Amazon-Reviews-2023 couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'raw_meta_Software' at C:\Users\user\.cache\huggingface\datasets\McAuley-Lab___amazon-reviews-2023\raw_meta_Software\0.0.0\16b76e0823d73bb8cff1e9c5e3e37dbc46ae3daee380417ae141f5e67d3ea8e8 (last modified on Sun Dec 21 21:49:27 2025).
#               main_category  \
# 0      Appstore for Android
# 1      Appstore for Android
# 2      Appstore for Android
# 3      Appstore for Android
# 4      Appstore for Android
# ...                     ...
# 89246              Software
# 89247              Software
# 89248                   NaN
# 89249                   NaN
# 89250              Software
#
#                                                    title  average_rating  \
# 0                                     Accupressure Guide             3.6
# 1      Ankylosaurus Fights Back - Smithsonian's Prehi...             4.0
# 2                                           Mahjong 2015             3.1
# 3                                  Jewels Brick Breakout             4.2
# 4                           Traffic Police: Off-Road Cub             3.3
# ...                                                  ...             ...
# 89246  How to Start a Commercial Loan Broker Plus Bus...             3.2
# 89247                            Norton Uninstall Deluxe             3.7
# 89248          Beginning Pro Tools LE 8 [Instant Access]             3.0
# 89249  Tell Me More Spanish Performance Version 9 (2 ...             1.5
# 89250  Veryfi - receipts & bills tracker, expense rep...             4.3
#
#        rating_number                                           features  \
# 0                NaN  [All the pressing point has been explained wit...
# 1                NaN  [ENCOURAGE literacy skills with highlighted na...
# 2                NaN  [Mahjong 2015 is a free solitaire matching gam...
# 3                NaN  [Game Features:, - Intuitive touch controls wi...
# 4                NaN  [In this game you will find:, - Killer police ...
# ...              ...                                                ...
# 89246            2.0  [Everything You Need to Know About Starting a ...
# 89247            2.0  [Safely removes programs and files you no long...
# 89248            3.0                                                 []
# 89249            2.0  [Spanish language-learning software with 2 lev...
# 89250            6.0  [Automated — Veryfi removes the hassle of manu...
#
#                                              description  price  \
# 0      [Acupressure technique is very ancient and ver...    0.0
# 1      [Join Ankylosaurus in this interactive book ap...   2.99
# 2      [Mahjong 2015 is a free solitaire matching gam...    0.0
# 3      [Jewels Brick Breakout is a glowing jewels bri...    0.0
# 4      [Become the best road police officer in Cube C...    0.0
# ...                                                  ...    ...
# 89246  [The How to Start a Commercial Loan Brokerage ...  29.95
# 89247  [The safe uninstaller from the makers of Norto...   None
# 89248  [This video takes you from start to finish on ...  15.95
# 89249  [From the Manufacturer, This award-winning lan...  209.0
# 89250  [Veryfi is a bookkeeper in your pocket. Ideal ...   None
#
#                                                   images  \
# 0      {'hi_res': [None, None, None, None], 'large': ...
# 1      {'hi_res': [None, None, None, None, None], 'la...
# 2      {'hi_res': [None, None, None], 'large': ['http...
# 3      {'hi_res': [None, None, None, None, None, None...
# 4      {'hi_res': [None, None, None, None], 'large': ...
# ...                                                  ...
# 89246  {'hi_res': [None, None, None, None, None], 'la...
# 89247  {'hi_res': [None], 'large': ['https://m.media-...
# 89248  {'hi_res': [None], 'large': ['https://m.media-...
# 89249  {'hi_res': [None], 'large': ['https://m.media-...
# 89250  {'hi_res': ['https://m.media-amazon.com/images...
#
#                                               videos                  store  \
# 0      {'title': [''], 'url': [''], 'user_id': ['']}              mAppsguru
# 1      {'title': [''], 'url': [''], 'user_id': ['']}  Oceanhouse Media, Inc
# 2      {'title': [''], 'url': [''], 'user_id': ['']}            sophiathach
# 3      {'title': [''], 'url': [''], 'user_id': ['']}            Bad Chicken
# 4      {'title': [''], 'url': [''], 'user_id': ['']}       Dast 2 For Metro
# ...                                              ...                    ...
# 89246        {'title': [], 'url': [], 'user_id': []}  HowToStartABusinessDB
# 89247        {'title': [], 'url': [], 'user_id': []}               Symantec
# 89248        {'title': [], 'url': [], 'user_id': []}           Alfred Music
# 89249        {'title': [], 'url': [], 'user_id': []}                Auralog
# 89250        {'title': [], 'url': [], 'user_id': []}                 Veryfi
#
#                                               categories  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 89246  [Software, Business & Office, Business & Marke...
# 89247                              [Software, Utilities]
# 89248                  [Software, Education & Reference]
# 89249       [Software, Education & Reference, Languages]
# 89250  [Software, Accounting & Finance, Business Acco...
#
#                                                  details parent_asin  \
# 0      {"Release Date": "2015", "Date first listed on...  B00VRPSGEO
# 1      {"Release Date": "2014", "Date first listed on...  B00NWQXXHQ
# 2      {"Release Date": "2014", "Date first listed on...  B00RFKP6AC
# 3      {"Release Date": "2015", "Date first listed on...  B00SP2QU0E
# 4      {"Release Date": "2016", "Date first listed on...  B01DZIT64O
# ...                                                  ...         ...
# 89246  {"Is Discontinued By Manufacturer": "No", "Ite...  B006KWVRGI
# 89247  {"Is Discontinued By Manufacturer": "No", "Pac...  B000J54PRA
# 89248  {"Language": "English", "Item model number": "...  B00MG0OHB0
# 89249  {"Language": "English, French", "Package Dimen...  B001GN6YUK
# 89250  {"Date First Available": "August 22, 2017", "M...  B0751Q59HC
#
#       bought_together subtitle author
# 0                None     None   None
# 1                None     None   None
# 2                None     None   None
# 3                None     None   None
# 4                None     None   None
# ...               ...      ...    ...
# 89246            None     None   None
# 89247            None     None   None
# 89248            None     None   None
# 89249            None     None   None
# 89250            None     None   None
#
# [89251 rows x 16 columns]

# %%
category_replace_dict = {
    "accounting": "accounting & finance",
    "antivirus": "antivirus & security",
    "education": "education & reference",
    "free one-day shipping i software": "free one-day shipping for software",
    "free one-day shipping on select software with your citi card": "free one-day shipping for software",
    "medicine": "medicine & health sciences",
    "photography": "photography & graphic design",
    "programming": "programming & web development",
    "spreadsheet": "spreadsheet & database",
    "training": "training & tutorials"
}

def parse_categories(cat_str):
    """Parse string representation of list into actual list"""
    if pd.isna(cat_str) or cat_str.strip() == "[]":
        return []
    try:
        parsed_list = ast.literal_eval(cat_str)

        modified_list = []

        for elem in parsed_list:
            modified_elem = (
                elem
                .lower()
                .replace("\'s", "")
            )

            if modified_elem in category_replace_dict.keys():
                modified_list.append(category_replace_dict[modified_elem])
            else:
                modified_list.append(modified_elem)

        return sorted(modified_list)

    except Exception as e:
        print(f"{e}: {cat_str}")
        return [cat_str]

def parse_videos(video_dict):
    for key, val in video_dict.items():
        if val == [""]:
            video_dict[key] = []

    return video_dict

modified_meta_df = meta_df.copy()

modified_meta_df["parent_asin"] = modified_meta_df["parent_asin"].str.lower()
modified_meta_df["title"] = modified_meta_df["title"].str.strip().str.lower()
modified_meta_df["main_category"] = modified_meta_df["main_category"].str.strip().str.lower()
modified_meta_df["categories"] = modified_meta_df["categories"].astype(str).apply(parse_categories)
modified_meta_df["videos"] = modified_meta_df["videos"].apply(parse_videos)

# modified_meta_df["average_rating"] = pd.to_numeric(modified_meta_df["average_rating"], errors="coerce")
modified_meta_df["rating_number"] = pd.to_numeric(modified_meta_df["rating_number"], errors="coerce")

modified_meta_df["store"] = modified_meta_df["store"].astype(str).str.strip().str.lower()
modified_meta_df["price"] = pd.to_numeric(modified_meta_df["price"], errors="coerce")

# Reorder columns
modified_meta_df = modified_meta_df[[
    "parent_asin",
    "title",
    "main_category",
    "categories",
    "description",
    "features",
    "details",
    "images",
    "videos",
    # "bought_together", # All rows contain None
    # "average_rating", # Removing since more concern about rating on platform than product page
    "rating_number",
    "store",
    # "subtitle", # All rows contain None
    # "author", # All rows contain None
    "price"
]]

# Rename columns
modified_meta_df = modified_meta_df.rename(columns={
    "title": "item_title",
    "images": "item_images",
    "videos": "item_videos",
    "rating_number": "item_rating"
})

modified_meta_df
# Out:
#       parent_asin                                         item_title  \
# 0      b00vrpsgeo                                 accupressure guide
# 1      b00nwqxxhq  ankylosaurus fights back - smithsonian's prehi...
# 2      b00rfkp6ac                                       mahjong 2015
# 3      b00sp2qu0e                              jewels brick breakout
# 4      b01dzit64o                       traffic police: off-road cub
# ...           ...                                                ...
# 89246  b006kwvrgi  how to start a commercial loan broker plus bus...
# 89247  b000j54pra                            norton uninstall deluxe
# 89248  b00mg0ohb0          beginning pro tools le 8 [instant access]
# 89249  b001gn6yuk  tell me more spanish performance version 9 (2 ...
# 89250  b0751q59hc  veryfi - receipts & bills tracker, expense rep...
#
#               main_category  \
# 0      appstore for android
# 1      appstore for android
# 2      appstore for android
# 3      appstore for android
# 4      appstore for android
# ...                     ...
# 89246              software
# 89247              software
# 89248                   NaN
# 89249                   NaN
# 89250              software
#
#                                               categories  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 89246  [business & marketing plans, business & office...
# 89247                              [software, utilities]
# 89248                  [education & reference, software]
# 89249       [education & reference, languages, software]
# 89250  [accounting & finance, business accounting, so...
#
#                                              description  \
# 0      [Acupressure technique is very ancient and ver...
# 1      [Join Ankylosaurus in this interactive book ap...
# 2      [Mahjong 2015 is a free solitaire matching gam...
# 3      [Jewels Brick Breakout is a glowing jewels bri...
# 4      [Become the best road police officer in Cube C...
# ...                                                  ...
# 89246  [The How to Start a Commercial Loan Brokerage ...
# 89247  [The safe uninstaller from the makers of Norto...
# 89248  [This video takes you from start to finish on ...
# 89249  [From the Manufacturer, This award-winning lan...
# 89250  [Veryfi is a bookkeeper in your pocket. Ideal ...
#
#                                                 features  \
# 0      [All the pressing point has been explained wit...
# 1      [ENCOURAGE literacy skills with highlighted na...
# 2      [Mahjong 2015 is a free solitaire matching gam...
# 3      [Game Features:, - Intuitive touch controls wi...
# 4      [In this game you will find:, - Killer police ...
# ...                                                  ...
# 89246  [Everything You Need to Know About Starting a ...
# 89247  [Safely removes programs and files you no long...
# 89248                                                 []
# 89249  [Spanish language-learning software with 2 lev...
# 89250  [Automated — Veryfi removes the hassle of manu...
#
#                                                  details  \
# 0      {"Release Date": "2015", "Date first listed on...
# 1      {"Release Date": "2014", "Date first listed on...
# 2      {"Release Date": "2014", "Date first listed on...
# 3      {"Release Date": "2015", "Date first listed on...
# 4      {"Release Date": "2016", "Date first listed on...
# ...                                                  ...
# 89246  {"Is Discontinued By Manufacturer": "No", "Ite...
# 89247  {"Is Discontinued By Manufacturer": "No", "Pac...
# 89248  {"Language": "English", "Item model number": "...
# 89249  {"Language": "English, French", "Package Dimen...
# 89250  {"Date First Available": "August 22, 2017", "M...
#
#                                              item_images  \
# 0      {'hi_res': [None, None, None, None], 'large': ...
# 1      {'hi_res': [None, None, None, None, None], 'la...
# 2      {'hi_res': [None, None, None], 'large': ['http...
# 3      {'hi_res': [None, None, None, None, None, None...
# 4      {'hi_res': [None, None, None, None], 'large': ...
# ...                                                  ...
# 89246  {'hi_res': [None, None, None, None, None], 'la...
# 89247  {'hi_res': [None], 'large': ['https://m.media-...
# 89248  {'hi_res': [None], 'large': ['https://m.media-...
# 89249  {'hi_res': [None], 'large': ['https://m.media-...
# 89250  {'hi_res': ['https://m.media-amazon.com/images...
#
#                                    item_videos  item_rating  \
# 0      {'title': [], 'url': [], 'user_id': []}          NaN
# 1      {'title': [], 'url': [], 'user_id': []}          NaN
# 2      {'title': [], 'url': [], 'user_id': []}          NaN
# 3      {'title': [], 'url': [], 'user_id': []}          NaN
# 4      {'title': [], 'url': [], 'user_id': []}          NaN
# ...                                        ...          ...
# 89246  {'title': [], 'url': [], 'user_id': []}          2.0
# 89247  {'title': [], 'url': [], 'user_id': []}          2.0
# 89248  {'title': [], 'url': [], 'user_id': []}          3.0
# 89249  {'title': [], 'url': [], 'user_id': []}          2.0
# 89250  {'title': [], 'url': [], 'user_id': []}          6.0
#
#                        store   price
# 0                  mappsguru    0.00
# 1      oceanhouse media, inc    2.99
# 2                sophiathach    0.00
# 3                bad chicken    0.00
# 4           dast 2 for metro    0.00
# ...                      ...     ...
# 89246  howtostartabusinessdb   29.95
# 89247               symantec     NaN
# 89248           alfred music   15.95
# 89249                auralog  209.00
# 89250                 veryfi     NaN
#
# [89251 rows x 12 columns]

# %% [markdown]
# ### Export Data

# %%
OUTPUT_DIR = "../data/output"

# Create output directory if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Export DataFrame
modified_review_df.to_parquet(f"{OUTPUT_DIR}/review_data.parquet", index=False)
modified_meta_df.to_parquet(f"{OUTPUT_DIR}/meta_data.parquet", index=False)

print("Complete")
# Out:
# Complete
